# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f = np.array([100.0, 1.0e3, 10.0e3, 100.0e3])
V_in = np.array([4.72, 4.72, 4.72, 4.72])
V_out = np.array([16.1, 16.2, 16.2, 15.9])
G = V_out/V_in

#p = f.argsort()
#f = f[p]
#G = G[p]

dB = 20*np.log10(G)

# %%
fig, ax = plt.subplots(1, 1)

fig.set_figheight(10)
fig.set_figwidth(10)
ax.set_xscale("log")
ax.plot(f, dB, "o-", label=r"$20log\frac{V_{out}}{V_{in}}$")
#ax.set_xlim(10**1.9, 10**3.5)
ax.set_title("Decibels vs Frequency")
plt.xlabel("Frequency $f$ (Hz)")
plt.ylabel("Decibels $(dB)$")
#plt.hlines(-3, 10**1, 10**3.5, linestyles="--", color="BLACK", label=r"-3dB")
#plt.vlines(944, -20, 1, linestyles="--", color="RED", label="944 Hz")
ax.set_ylim(0, 16)
ax.legend(prop={'size': 16})
plt.show()

# %%
f = np.array([20.0, 60.0, 100.0, 400.0, 1.0e3, 2.0e3, 6.0e3, 20.0e3, 30.0e3, 40.0e3, 50.0e3, 60.0e3, 70.0e3, 80.0e3, 90.0e3, 100.0e3, 110.0e3, 120.0e3, 130.0e3, 140.0e3, 160.0e3, 180.0e3, 200.0e3, 250.0e3, 300.0e3, 350.0e3, 400.0e3, 450.0e3, 500.0e3, 550.0e3, 600.0e3, 700.0e3, 800.0e3, 900.0e3, 1.0e6])
V_in = np.array([0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529, 0.529])
V_out = np.array([15.8, 15.8, 15.8, 15.8, 15.9, 16.1, 16.2, 15.8, 15.5, 15.1, 14.8, 14.1, 13.5, 13.1, 12.6, 12.2, 12.1, 11.7, 11.1, 10.5, 9.7, 9.1, 8.5, 7.2, 6.2, 5.7, 5.2, 4.7, 4.4, 4.2, 3.7, 3.3, 3.0, 2.7, 2.6])
G = V_out/V_in

#p = f.argsort()
#f = f[p]
#G = G[p]

dB = 20*np.log10(G)

# %%
fig, ax = plt.subplots(1, 1)

fig.set_figheight(10)
fig.set_figwidth(10)
ax.set_xscale("log")
ax.plot(f, dB, "o-", label=r"$20log\frac{V_{out}}{V_{in}}$")
#ax.set_xlim(10**1.9, 10**3.5)
ax.set_title("Decibels vs Frequency")
plt.xlabel("Frequency $f$ (Hz)")
plt.ylabel("Decibels $(dB)$")
#plt.hlines(-3, 10**1, 10**3.5, linestyles="--", color="BLACK", label=r"-3dB")
#plt.vlines(944, -20, 1, linestyles="--", color="RED", label="944 Hz")
#ax.set_ylim(0, 16)
ax.legend(prop={'size': 16})
plt.show()

# %%
f1 = np.array([100.0, 500.0, 1.0e3, 1.5e3, 2.0e3, 2.5e3, 3.0e3, 3.5e3, 4.0e3, 5.0e3, 6.0e3, 7.0e3, 8.0e3, 9.0e3, 10.0e3, 12.0e3, 14.0e3, 16.0e3, 18.0e3, 20.0e3, 30.0e3, 50.0e3, 80.0e3, 150.0e3, 300.0e3, 1.0e6])
V_in1 = np.array([10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3])
V_out1 = np.array([5.88, 5.68, 5.24, 4.68, 4.02, 3.64, 3.24, 2.96, 2.48, 2.10, 1.82, 1.58, 1.46, 1.32, 1.20, 1.02, 0.9, 0.8, 0.72, 0.64, 0.5, 0.36, 0.3, 0.22, 0.18, 0.16])
G1 = V_out1/V_in1

#p = f.argsort()
#f = f[p]
#G = G[p]

dB1 = 20*np.log10(G1)

# %%
f2 = np.array([100.0, 500.0, 1.0e3, 1.5e3, 2.0e3, 2.5e3, 3.0e3, 3.5e3, 4.0e3, 4.5e3, 5.0e3, 5.5e3, 6.0e3, 7.0e3, 8.0e3, 9.0e3, 10.0e3, 12.0e3, 14.0e3, 16.0e3, 18.0e3, 20.0e3, 30.0e3, 50.0e3, 80.0e3, 150.0e3, 300.0e3, 1.0e6])
V_in2 = np.array([10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3, 10.0e-3])
V_out2 = np.array([5.92, 5.92, 5.88, 5.80, 5.68, 5.56, 5.40, 5.16, 5.04, 4.88, 4.72, 4.56, 4.44, 4.00, 3.76, 3.56, 3.32, 2.80, 2.60, 2.36, 2.16, 2.00, 1.40, 1.00, 0.640, 0.400, 0.320, 0.240])
G2 = V_out2/V_in2

#p = f.argsort()
#f = f[p]
#G = G[p]

dB2 = 20*np.log10(G2)

# %%
fig, ax = plt.subplots(1, 1)

fig.set_figheight(10)
fig.set_figwidth(10)
ax.set_xscale("log")
ax.plot(f1, dB1, "o-", label="741 Gain")
ax.plot(f2, dB2, "o-", label="LF411 Gain", color='RED')
ax.set_xlim(10**1.9, 10**6.1)
ax.set_title("Gain vs Frequency")
plt.xlabel("Frequency $f$ (Hz)")
plt.ylabel("Decibels $(dB)$")
plt.hlines(52.41, 10**1, 10**7, linestyles="--", color="BLACK", label=r"-3dB")
plt.vlines(10**3.27, 20, 60, linestyles="--", color="BLUE", label="~1.86 kHz")
plt.vlines(10**3.81, 20, 60, linestyles="--", color="RED", label="~6.46 kHz")
ax.set_ylim(23, 57)
ax.legend(prop={'size': 16})
plt.show()

# %%
dB1
# Out:
# array([55.38754652, 55.08696671, 54.38662574, 53.40491706, 52.08452106,
#        51.22202767, 50.2109002 , 49.42583422, 47.88903362, 46.44438589,
#        45.20142776, 43.97314174, 43.28705712, 42.41147862, 41.58362492,
#        40.17200344, 39.08485019, 38.06179974, 37.14664993, 36.12359948,
#        33.97940009, 31.12605002, 29.54242509, 26.84845362, 25.1054501 ,
#        24.08239965])
